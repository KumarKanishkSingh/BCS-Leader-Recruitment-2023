# %%
import pandas as pd
import random
import string

# %%
# load the CSV file into a pandas dataframe
df = pd.read_csv('/content/train - train.csv')

# %%
# create a list of negative sentiments
neg_sentiments = ["terrible", "bad", "frustrating", "disappointing", "difficult"]

# %%
# iterate over the dataframe and randomly generate negative samples
neg_samples = []
for index, row in df.iterrows():
    # check if the label is 1 (positive)
    if row['label'] == 1:
        # generate a negative sample with opposite sentiment
        neg_text = random.choice(neg_sentiments) + " " + row['reason']
        neg_samples.append({'text': neg_text, 'label': 0})

# %%
# convert the negative samples to a pandas dataframe and save to CSV
neg_df = pd.DataFrame(neg_samples)
neg_df.to_csv('neg_samples.csv', index=False)
neg_df
# Out:
#                                                    text  label
# 0     disappointing good app for conducting online c...      0
# 1                      frustrating app is user-friendly      0
# 2               frustrating good for video conferencing      0
# 3               frustrating unable to download zoom app      0
# 4                  frustrating want to download the app      0
# ...                                                 ...    ...
# 2056              frustrating unable to use with jio tv      0
# 2057                      terrible netflix ui is better      0
# 2058        terrible unable to use disney on chromecast      0
# 2059          difficult unable to use disney plus on tv      0
# 2060  bad sound keeps playing even after closing the...      0
#
# [2061 rows x 2 columns]

# %%
column_name = df['reason']
common_column=df['text']

# %%
merged_df = pd.merge(neg_df, column_name, on=common_column)
merged_df
# Out:
#                                                   key_0  \
# 0         this is an amazing app for online classes!but
# 1                        very practical and easy to use
# 2         this app is very good for video conferencing.
# 3                      i can not download this zoom app
# 4                    i am not able to download this app
# ...                                                 ...
# 2060                  i am not getting jio tv properly.
# 2061                 (learn from the netflix interface)
# 2062  hello,\ndisney+ must also be installed on chro...
# 2063  it is a shame that disney+ does not work on tv...
# 2064  i have to close and reload the app over and ov...
#
#                                                    text  label  \
# 0     disappointing good app for conducting online c...      0
# 1                      frustrating app is user-friendly      0
# 2               frustrating good for video conferencing      0
# ...

# %%
merged_df = merged_df.drop('reason', axis=1)

# %%
merged_df = merged_df[['key_0', 'text', 'label']]

# %%
merged_df.rename(columns = {'key_0':'text', 'text':'reason'}, inplace = True)

# %%
merged_df
# Out:
#                                                    text  \
# 0         this is an amazing app for online classes!but
# 1                        very practical and easy to use
# 2         this app is very good for video conferencing.
# 3                      i can not download this zoom app
# 4                    i am not able to download this app
# ...                                                 ...
# 2060                  i am not getting jio tv properly.
# 2061                 (learn from the netflix interface)
# 2062  hello,\ndisney+ must also be installed on chro...
# 2063  it is a shame that disney+ does not work on tv...
# 2064  i have to close and reload the app over and ov...
#
#                                                  reason  label
# 0     disappointing good app for conducting online c...      0
# 1                      frustrating app is user-friendly      0
# 2               frustrating good for video conferencing      0
# ...

# %%
final_df = pd.concat([df, merged_df], ignore_index=True)

# %%
final_df.to_csv('Train.csv', index=False)
